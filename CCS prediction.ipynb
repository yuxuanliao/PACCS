# %% [markdown]
# # CCS prediction

# %%
from PACCS.Prediction import *

# %% [markdown]
# ## Please load the file required for predicting CCS values

# %%
input_path = './data/external_test_set_vpa_mz.csv'

# %% [markdown]
# ## Please load the PACCS model

# %%
model_path = './model/model.pt'

# %% [markdown]
# ## Provide the directory path where the predicted CCS values will be saved

# %%
output_path = './data/external_test_set_prediction.csv'

# %% [markdown]
# ## Use the PACCS model to predict the CCS values

# %%
PACCS_predict(input_path, model_path, output_path)
# Out:
# ## Read data :  1172
# ## All Atoms :  ['As', 'Br', 'C', 'Cl', 'F', 'I', 'N', 'O', 'P', 'S', 'Se']
# ## All Adduct types:  ['[M+H]+', '[M+Na]+', '[M-H]-']
# Test length : 1172
# 100%|██████████████████████████████████████████████████████████████████████████████| 1172/1172 [02:48<00:00,  6.97it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1172/1172 [00:17<00:00, 66.22it/s]
# ## CCS prediction has been completed
# R2 Score : 0.9771023286959324
# Mean Absolute Error : 3.400636497211131
# Median Absolute Error : 2.417877197265625
# Median Relative Error : 1.4759262609937942 %
# Mean Relative Error : 1.9087435369085852 %
# Root Mean Squared Error : 4.734970541140459
# Mean Squared Error : 22.419946025467976
